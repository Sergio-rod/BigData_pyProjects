# %%
from pymongo import MongoClient as mc
cluster= mc('mongodb+srv://Sergio:mFd4rnKsL5oYZIZB@cluster0.77rvvvm.mongodb.net/?retryWrites=true&w=majority')

# %%
db= cluster.dbTest

# %%
collection=db['adn'] #Nombre de nuestra tabla, contentenedora de valores

# %%
import pandas as pd

# %%
data = collection.find()
# Out:
# <pymongo.cursor.Cursor object at 0x7fb8e80aafa0>

# %%
type(data)
# Out:
# pymongo.cursor.Cursor

# %%
l1 = list(data)
print(l1)
# Out:
# [{'_id': 0, 'name': 'camote thaliana', 'data': [{'t-SNE-1': 10.846841, 't-SNE-2': -16.71258}, {'t-SNE-1': 24.794334, 't-SNE-2': -16.775398}, {'t-SNE-1': 2.953309, 't-SNE-2': 13.379048}, {'t-SNE-1': 27.262146, 't-SNE-2': -31.88669}, {'t-SNE-1': -23.015728, 't-SNE-2': 64.468376}, {'t-SNE-1': 36.790676, 't-SNE-2': -18.019236}, {'t-SNE-1': 81.03583, 't-SNE-2': -7.6142125}, {'t-SNE-1': -30.387047, 't-SNE-2': 63.77186}, {'t-SNE-1': -15.39652, 't-SNE-2': -2.9790528}, {'t-SNE-1': -46.21859, 't-SNE-2': 11.978482}, {'t-SNE-1': -60.82239, 't-SNE-2': -40.374413}, {'t-SNE-1': 79.09517, 't-SNE-2': -8.604884}, {'t-SNE-1': -37.153156, 't-SNE-2': -18.858006}, {'t-SNE-1': -73.48587, 't-SNE-2': 1.9712921}, {'t-SNE-1': 75.5153, 't-SNE-2': -26.25351}, {'t-SNE-1': -11.774027, 't-SNE-2': 2.696394}, {'t-SNE-1': -22.526203, 't-SNE-2': -15.650103}, {'t-SNE-1': 1.014268, 't-SNE-2': 52.409912}, {'t-SNE-1': 19.667788, 't-SNE-2': 21.32458}, {'t-SNE-1': -80.85691, 't-SNE-2': 0.29213288}, {'t-SNE-1': 19.852867, 't-SNE-2': 30.855186}, {'t-SNE-1': -7.471318, 't-SNE-2': 18.757692}, {'t-SNE-1': -68.338066, 't-SNE-2': -6.346191}, {'t-SNE-1': 29.552477, 't-SNE-2': 33.758324}, {'t-SNE-1': 5.1655316, 't-SNE-2': 18.799715}, {'t-SNE-1': 19.996674, 't-SNE-2': -10.614891}, {'t-SNE-1': 33.987926, 't-SNE-2': -8.628308}, {'t-SNE-1': 31.409191, 't-SNE-2': 29.927109}, {'t-SNE-1': 29.026451, 't-SNE-2': -12.218949}, {'t-SNE-1': -72.20213, 't-SNE-2': 0.21854489}, {'t-SNE-1': -40.372894, 't-SNE-2': -14.531695}, {'t-SNE-1': 31.51973, 't-SNE-2': 47.964268}, {'t-SNE-1': 7.129553, 't-SNE-2': 14.311046}, {'t-SNE-1': 16.110907, 't-SNE-2': -32.52121}, {'t-SNE-1': 35.147453, 't-SNE-2': -65.073654}, {'t-SNE-1': -6.7435513, 't-SNE-2': -52.916557}, {'t-SNE-1': -44.625835, 't-SNE-2': 27.017687}, {'t-SNE-1': 10.849508, 't-SNE-2': 16.639433}, {'t-SNE-1': 27.61716, 't-SNE-2': 43.83443}, {'t-SNE-1': 35.495655, 't-SNE-2': -63.920246}, {'t-SNE-1': -4.134805, 't-SNE-2': -49.971294}, {'t-SNE-1': -36.592247, 't-SNE-2': 54.854004}, {'t-SNE-1': 3.6634693, 't-SNE-2': -1.6532351}, {'t-SNE-1': 30.257286, 't-SNE-2': -21.392036}, {'t-SNE-1': 3.487294, 't-SNE-2': 11.879071}, {'t-SNE-1': 10.48272, 't-SNE-2': 16.913815}, {'t-SNE-1': -6.6594977, 't-SNE-2': 16.003056}, {'t-SNE-1': 69.03472, 't-SNE-2': -14.420045}, {'t-SNE-1': 41.626987, 't-SNE-2': -12.963191}, {'t-SNE-1': 22.040215, 't-SNE-2': -8.346808}, {'t-SNE-1': -51.02639, 't-SNE-2': 54.357243}, {'t-SNE-1': -7.0874696, 't-SNE-2': 42.152634}, {'t-SNE-1': 34.895374, 't-SNE-2': 50.366756}, {'t-SNE-1': 1.2222531, 't-SNE-2': 52.61128}, {'t-SNE-1': 43.24275, 't-SNE-2': -22.481049}, {'t-SNE-1': 40.931152, 't-SNE-2': -61.989235}, {'t-SNE-1': 3.644356, 't-SNE-2': 39.892746}, {'t-SNE-1': -18.0871, 't-SNE-2': -65.91649}, {'t-SNE-1': 28.232721, 't-SNE-2': 47.72172}, {'t-SNE-1': -43.25959, 't-SNE-2': 13.233326}, {'t-SNE-1': -17.63084, 't-SNE-2': -7.7109485}, {'t-SNE-1': -52.276855, 't-SNE-2': 29.086454}, {'t-SNE-1': 31.168036, 't-SNE-2': 61.940422}, {'t-SNE-1': -48.310013, 't-SNE-2': 30.104786}, {'t-SNE-1': 35.03216, 't-SNE-2': 62.717827}, {'t-SNE-1': 13.686868, 't-SNE-2': -12.970217}, {'t-SNE-1': 15.655424, 't-SNE-2': -13.237315}, {'t-SNE-1': -57.610035, 't-SNE-2': -28.54787}, {'t-SNE-1': -70.48103, 't-SNE-2': -3.2993488}, {'t-SNE-1': -44.03357, 't-SNE-2': -19.707146}, {'t-SNE-1': -46.201527, 't-SNE-2': 44.507877}, {'t-SNE-1': -47.488037, 't-SNE-2': -28.866028}, {'t-SNE-1': 75.30372, 't-SNE-2': -13.836317}, {'t-SNE-1': 20.712078, 't-SNE-2': -29.26158}, {'t-SNE-1': -18.476673, 't-SNE-2': -11.106185}, {'t-SNE-1': -3.9913292, 't-SNE-2': -49.918015}, {'t-SNE-1': 39.133297, 't-SNE-2': -60.47322}, {'t-SNE-1': -12.852584, 't-SNE-2': -55.930107}, {'t-SNE-1': 71.904945, 't-SNE-2': -23.491669}, {'t-SNE-1': -51.85329, 't-SNE-2': -18.657509}, {'t-SNE-1': -9.4866, 't-SNE-2': 36.31664}, {'t-SNE-1': -18.300966, 't-SNE-2': -11.769968}, {'t-SNE-1': 32.827984, 't-SNE-2': 31.333086}, {'t-SNE-1': 20.165424, 't-SNE-2': 28.538645}, {'t-SNE-1': -68.619095, 't-SNE-2': -6.2097325}, {'t-SNE-1' ...

# %%
l1Data=l1[0]['data']

# %%
dfData = pd.DataFrame(l1Data)

# %%
dfData
# Out:
#         t-SNE-1    t-SNE-2
# 0     10.846841 -16.712580
# 1     24.794334 -16.775398
# 2      2.953309  13.379048
# 3     27.262146 -31.886690
# 4    -23.015728  64.468376
# ...         ...        ...
# 4401 -15.211057 -69.717155
# 4402  -9.403443 -62.847458
# 4403 -17.546083 -10.295582
# 4404  -8.512799  16.375420
# 4405 -17.493050  -2.631812
#
# [4406 rows x 2 columns]
